# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
table = pd.read_html('https://coinmarketcap.com/trending-cryptocurrencies/')
trend = table[0]
trending = trend[['Name','Price','24h','Market Cap','Volume(24h)']]
trending.to_csv('trending_crypto.csv')
trending
# Out:
#                              Name          Price     24h        Market Cap  \
# 0                     Celsius1CEL        $0.9666   5.16%      $230,884,061
# 1              Terra Classic2LUNC    $0.00005724   1.33%      $375,037,830
# 2                     Bitcoin3BTC     $20,729.64   4.02%  $395,422,878,430
# 3                      Solana4SOL         $37.55   9.37%   $12,865,292,982
# 4                  Shiba Inu5SHIB    $0.00001009   5.41%    $5,537,544,780
# 5                    Ethereum6ETH      $1,127.55   7.22%  $136,748,959,962
# 6                       USDD7USDD        $0.9758   0.13%      $705,823,106
# 7                   Dogecoin8DOGE       $0.06364   3.60%    $8,443,366,429
# 8   Green Satoshi Token (SOL)9GST        $0.1851   5.89%       $29,139,326
# 9                  Polygon10MATIC        $0.5416  20.43%    $4,333,805,751
# 10            Oasis Network11ROSE       $0.05258   4.17%      $264,328,222
# ...
